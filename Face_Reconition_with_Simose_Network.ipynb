# %%
# import dependencies

import os
import cv2
import os 
import random
import numpy as np
from matplotlib import pyplot as plt

# %%
# importing tensorflow 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Layer, Conv2D, Dense, MaxPooling2D, Input, Flatten
import tensorflow as tf

# %%
# Avoid oom growth error by setting up GPU memory consumption growth
gpus = tf.config.experimental.list_physical_devices('GPU')
print(len(gpus))
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# 0

# %%
# Folder Structure
main_path = '/content/data/'
POS_PATH = os.path.join(main_path, 'positive')
NEG_PATH = os.path .join(main_path, 'negative')
ANC_PATH = os.path.join(main_path, 'anchor')

# %%
# making directries
os.makedirs(POS_PATH)
os.mkdir(NEG_PATH)
os.mkdir(ANC_PATH)

# %%
# http://vis-www.cs.umass.edu/lfw/
# !tar -xf lfw.tgz
# Out:
# gzip: stdin: unexpected end of file
# tar: Unexpected EOF in archive
# tar: Unexpected EOF in archive
# tar: Error is not recoverable: exiting now

# %%
# Moving LFW Images to the following repository data/negative 
for directory in os.listdir('lfw'):
    for file in os.listdir(os.path.join('lfw', directory)):
        EX_PATH = os.path.join('lfw', directory, file)
        NEW_PATH = os.path.join(NEG_PATH, file)
        os.replace(EX_PATH, NEW_PATH)

# %%
for directory in os.listdir('lfw'):
    for file in os.path.join('lfw', directory):
        print(os.path.join('lfw', directory, file))
        print(os.path.join(NEG_PATH, file))
# Out:
# lfw/Darren_Clarke/l
# /content/data/negative/l
# lfw/Darren_Clarke/f
# /content/data/negative/f
# lfw/Darren_Clarke/w
# /content/data/negative/w
# /
# /
# lfw/Darren_Clarke/D
# /content/data/negative/D
# lfw/Darren_Clarke/a
# /content/data/negative/a
# lfw/Darren_Clarke/r
# /content/data/negative/r
# lfw/Darren_Clarke/r
# /content/data/negative/r
# lfw/Darren_Clarke/e
# /content/data/negative/e
# lfw/Darren_Clarke/n
# /content/data/negative/n
# lfw/Darren_Clarke/_
# /content/data/negative/_
# lfw/Darren_Clarke/C
# /content/data/negative/C
# lfw/Darren_Clarke/l
# /content/data/negative/l
# lfw/Darren_Clarke/a
# /content/data/negative/a
# lfw/Darren_Clarke/r
# /content/data/negative/r
# lfw/Darren_Clarke/k
# /content/data/negative/k
# lfw/Darren_Clarke/e
# /content/data/negative/e
# lfw/Paul_ONeill/l
# /content/data/negative/l
# lfw/Paul_ONeill/f
# /content/data/negative/f
# lfw/Paul_ONeill/w
# /content/data/negative/w
# /
# /
# lfw/Paul_ONeill/P
# /content/data/negative/P
# ...
